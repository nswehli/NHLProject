# %%
from ohmysportsfeedspy import MySportsFeeds
import simplejson as json
import pandas as pd

# %%
msf = MySportsFeeds(version="1.2")
msf.authenticate("ff3a9d40-4a07-42fb-91f6-00446c","6dRSvQq4F3evp!C")

# %%
#Available stats for each game by a team
 
TeamGameLogs = msf.msf_get_data(league='nhl',season=season,feed='team_gamelogs',team=5, format='json')
TeamGameLogs["teamgamelogs"]["gamelogs"][0]["stats"]
# Out:
# {'Wins': {'@category': 'Standings', '@abbreviation': 'W', '#text': '0'},
#  'Losses': {'@category': 'Standings', '@abbreviation': 'L', '#text': '0'},
#  'OvertimeWins': {'@category': 'Standings',
#   '@abbreviation': 'OTW',
#   '#text': '0'},
#  'OvertimeLosses': {'@category': 'Standings',
#   '@abbreviation': 'OTL',
#   '#text': '1'},
#  'GoalsFor': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GF',
#   '#text': '2'},
#  'GoalsAgainst': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GA',
#   '#text': '2'},
#  'FaceoffWins': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O W',
#   '#text': '41'},
#  'FaceoffLosses': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O L',
#   '#text': '28'},
#  'FaceoffPercent': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O %',
#   '#text': '59.4'},
#  'Powerplays': {'@category': 'Powerplay', '@abbreviation': 'PP', '#text': '3'},
#  'PowerplayGoals': {'@category': 'Powerplay',
#   '@abbreviation': 'PPG',
#   '#text': '0'},
#  'PowerplayPercent': {'@category': 'Powerplay',
#   '@abbreviation': 'PP%',
#   '#text': '0.0'},
#  'PenaltyKills': {'@category': 'Powerplay',
#   '@abbreviation': 'PK',
#   '#text': '2'},
#  'PenaltyKillGoalsAllowed': {'@category': 'Powerplay',
#   '@abbreviation': 'PKGA',
#   '#text': '1'},
#  'PenaltyKillPercent': {'@category': 'Powerplay',
#   '@abbreviation': 'PK%',
#   '#text': '50.0'},
#  'ShorthandedGoalsFor': {'@category': 'Powerplay',
#   '@abbreviation': 'SHGF',
#   '#text': '0'},
#  'ShorthandedGoalsAgainst': {'@category': 'Powerplay',
#   '@abbreviation': 'SHGA',
#   '#text': '0'},
#  'Points': {'@category': 'Standings', '@abbreviation': 'Pts', '#text': '1'},
#  'Shots': {'@category': 'Miscellaneous', '@abbreviation': 'Sh', '#text': '41'},
#  'Penalties': {'@category': 'Miscellaneous',
#   '@abbreviation': 'Pn',
#   '#text': '3'},
#  'PenaltyMinutes': {'@category': 'Miscellaneous',
#   '@abbreviation': 'PIM',
#   '#text': '9'},
#  'Hits': {'@category': 'Miscellaneous', '@abbreviation': 'Ht', '#text': '21'}}

# %%
## Building a loop to go through each season,each team, each game
## What is missing is the full list of team IDS, and including a Try and Except.
## we can use this lopp to build the dataframe of the stats we need.
##This is a limited test over three seasons

#Defining Lists

ListSeason=[]
ListTeam=[]
ListblockedShots=[]
ListgoalsAgainst=[]
ListpenaltyKillPercent=[]
ListWin=[]


#Defining seasons

TargetSeasons=["2018-2019-regular",
              "2017-2018-regular",
              "2016-2017-regular",]

#Creating loops to fill the lists
try:
    for season in TargetSeasons:
        for team in range (1,10):
            for game in range (1,10):
                TeamGameLogs = msf.msf_get_data(league='nhl',season=season,feed='team_gamelogs',team=team, format='json')
                BlockedShots=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["BlockedShots"]["#text"]
                win=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["Wins"]["#text"]
                goalsAgainst=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["GoalsAgainst"]["#text"]
                PenaltyKillPercent=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["PenaltyKillPercent"]["#text"]

                ## Adding values to list
                ListSeason.append(season)
                ListTeam.append(team)
                ListblockedShots.append(BlockedShots)
                ListgoalsAgainst.append(GoalsAgainst)
                ListWin.append(win)
                ListpenaltyKillPercent.append(PenaltyKillPercent)
except:
    print("Error Found")
    
    
print ("Completed")

# %%
#zipping the lists and creating a dataframe

ZipList=list(zip(ListSeason, ListTeam,ListblockedShots,ListgoalsAgainst,ListpenaltyKillPercent,ListWin))

Gamesdf = pd.DataFrame(ZipList, columns = ["Season","Team", "BlockedShots","Goals Against", "Penalty Kill Percent","Win"])
Gamesdf
# Out:
#                 Season  Team BlockedShots Goals Against Penalty Kill Percent  \
# 0    2018-2019-regular     1           13             3                 50.0
# 1    2018-2019-regular     1           13             3                 75.0
# 2    2018-2019-regular     1           20             3                100.0
# 3    2018-2019-regular     1           15             3                 75.0
# 4    2018-2019-regular     1           17             3                 66.7
# 5    2018-2019-regular     1           17             3                 50.0
# 6    2018-2019-regular     1           16             3                100.0
# 7    2018-2019-regular     1           18             3                 83.3
# 8    2018-2019-regular     1           19             3                100.0
# 9    2018-2019-regular     2           13             3                 50.0
# 10   2018-2019-regular     2           13             3                 75.0
# 11   2018-2019-regular     2           20             3                100.0
# 12   2018-2019-regular     2           15             3                 75.0
# 13   2018-2019-regular     2           17             3                 66.7
# 14   2018-2019-regular     2           17             3                 50.0
# 15   2018-2019-regular     2           16             3                100.0
# 16   2018-2019-regular     2           18             3                 83.3
# 17   2018-2019-regular     2           19             3                100.0
# 18   2018-2019-regular     3           13             3                 50.0
# 19   2018-2019-regular     3           13             3                 75.0
# 20   2018-2019-regular     3           20             3                100.0
# 21   2018-2019-regular     3           15             3                 75.0
# 22   2018-2019-regular     3           17             3                 66.7
# 23   2018-2019-regular     3           17             3                 50.0
# 24   2018-2019-regular     3           16             3                100.0
# 25   2018-2019-regular     3           18             3                 83.3
