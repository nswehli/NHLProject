# %%
from ohmysportsfeedspy import MySportsFeeds
import simplejson as json

# %%
msf = MySportsFeeds(version="1.2")
msf.authenticate("ff3a9d40-4a07-42fb-91f6-00446c","6dRSvQq4F3evp!C")

# %%
#Game by Game stat
#Testing connection
#Example 
output = msf.msf_get_data(league='nhl',season='2018-2019-regular',feed='game_playbyplay',gameid="20181207-MIN-EDM", format='json')
output
# Out:
# {'gameplaybyplay': {'lastUpdatedOn': '2019-10-24 10:16:18 AM',
#   'game': {'date': '2018-12-07',
#    'time': '9:00PM',
#    'awayTeam': {'ID': '25',
#     'City': 'Minnesota',
#     'Name': 'Wild',
#     'Abbreviation': 'MIN'},
#    'homeTeam': {'ID': '24',
#     'City': 'Edmonton',
#     'Name': 'Oilers',
#     'Abbreviation': 'EDM'},
#    'location': 'Rogers Place'},
#   'plays': {'play': [{'period': '1',
#      'time': '0:00',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '0:28',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '0:42',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '0:46',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '1:15',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '1:18',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '1:42',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '2:29',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '2:46',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5372',
#        'LastName': 'Rattie',
#        'FirstName': 'Ty',
#        'JerseyNumber': '8',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '4:14',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'assist1Player': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '4:14',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '4:20',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '4:25',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '14152',
#        'LastName': 'Greenway',
#        'FirstName': 'Jordan',
#        'JerseyNumber': '18',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '4:26',
#      'faceoff': {'awayPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '4:51',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '5:24',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '5:29',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '5:35',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '5:35',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '5:57',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '6:09',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '12486',
#        'LastName': 'Seeler',
#        'FirstName': 'Nick',
#        'JerseyNumber': '36',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '6:11',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5093',
#        'LastName': 'Zucker',
#        'FirstName': 'Jason',
#        'JerseyNumber': '16',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '6:22',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5055',
#        'LastName': 'Foligno',
#        'FirstName': 'Marcus',
#        'JerseyNumber': '17',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '7:00',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '7:03',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '7:14',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '7:42',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '7:44',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '7:44',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'assist1Player': {'ID': '5875',
#        'LastName': 'Khaira',
#        'FirstName': 'Jujhar',
#        'JerseyNumber': '16',
#        'Position': 'LW'},
#       'assist2Player': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '7:51',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '7:58',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '8:12',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '8:42',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'assist1Player': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'},
#       'assist2Player': {'ID': '5914',
#        'LastName': 'Gravel',
#        'FirstName': 'Kevin',
#        'JerseyNumber': '5',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '8:42',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '9:52',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5372',
#        'LastName': 'Rattie',
#        'FirstName': 'Ty',
#        'JerseyNumber': '8',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '10:01',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '10:06',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '10:31',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5039',
#        'LastName': 'Kassian',
#        'FirstName': 'Zack',
#        'JerseyNumber': '44',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '10:38',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'MIN',
#       'goalScorer': {'ID': '5055',
#        'LastName': 'Foligno',
#        'FirstName': 'Marcus',
#        'JerseyNumber': '17',
#        'Position': 'LW'},
#       'assist1Player': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'assist2Player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '10:38',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '10:59',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '11:13',
#      'faceoff': {'awayPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '11:20',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '11:26',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '11:36',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '12:00',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '12:34',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5914',
#        'LastName': 'Gravel',
#        'FirstName': 'Kevin',
#        'JerseyNumber': '5',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '12:42',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '12:48',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '13:07',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '13:10',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '13:25',
#      'faceoff': {'awayPlayer': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '13:50',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '13:52',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '14:13',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '12249',
#        'LastName': 'Zykov',
#        'FirstName': 'Valentin',
#        'JerseyNumber': '73',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '14:49',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '14:54',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '15:12',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '15:39',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '15:55',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '16:06',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5184',
#        'LastName': 'Pateryn',
#        'FirstName': 'Greg',
#        'JerseyNumber': '29',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '16:27',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '9630',
#        'LastName': 'Puljujarvi',
#        'FirstName': 'Jesse',
#        'JerseyNumber': '98',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '16:55',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5914',
#        'LastName': 'Gravel',
#        'FirstName': 'Kevin',
#        'JerseyNumber': '5',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '17:06',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5123',
#        'LastName': 'Brodin',
#        'FirstName': 'Jonas',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '17:08',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5914',
#        'LastName': 'Gravel',
#        'FirstName': 'Kevin',
#        'JerseyNumber': '5',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '17:16',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '17:42',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '18:00',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '18:16',
#      'faceoff': {'awayPlayer': {'ID': '14152',
#        'LastName': 'Greenway',
#        'FirstName': 'Jordan',
#        'JerseyNumber': '18',
#        'Position': 'LW'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '18:23',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '18:48',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '18:56',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '19:03',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'}}},
#     {'period': '1',
#      'time': '19:23',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '1',
#      'time': '19:23',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '9630',
#        'LastName': 'Puljujarvi',
#        'FirstName': 'Jesse',
#        'JerseyNumber': '98',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '19:34',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'}}},
#     {'period': '1',
#      'time': '19:40',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'}}},
#     {'period': '1',
#      'time': '19:47',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '1',
#      'time': '19:58',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '9630',
#        'LastName': 'Puljujarvi',
#        'FirstName': 'Jesse',
#        'JerseyNumber': '98',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '0:00',
#      'faceoff': {'awayPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '0:17',
#      'faceoff': {'awayPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '0:32',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '0:38',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '1:06',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '1:32',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5093',
#        'LastName': 'Zucker',
#        'FirstName': 'Jason',
#        'JerseyNumber': '16',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '1:50',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5200',
#        'LastName': 'Chiasson',
#        'FirstName': 'Alex',
#        'JerseyNumber': '39',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '2:06',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '2:11',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5093',
#        'LastName': 'Zucker',
#        'FirstName': 'Jason',
#        'JerseyNumber': '16',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '2:55',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '3:11',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '3:17',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '3:21',
#      'faceoff': {'awayPlayer': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '3:32',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '3:34',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '4:35',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '4:37',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '4:54',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '5:11',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '5:32',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '5:59',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '6:06',
#      'penalty': {'teamAbbreviation': 'EDM',
#       'penalizedPlayer': {'ID': '12249',
#        'LastName': 'Zykov',
#        'FirstName': 'Valentin',
#        'JerseyNumber': '73',
#        'Position': 'LW'},
#       'severity': 'Minor',
#       'durationMinutes': '2',
#       'type': 'Holding'}},
#     {'period': '2',
#      'time': '6:06',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '6:43',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '7:34',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '8:42',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '8:42',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '9:26',
#      'faceoff': {'awayPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '9:38',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '9:55',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '9:59',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '10:17',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '10:19',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '10:25',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '10:44',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '10:46',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '10:48',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '10:49',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '10:50',
#      'penalty': {'teamAbbreviation': 'EDM',
#       'penalizedPlayer': {'ID': '5001',
#        'LastName': 'Klefbom',
#        'FirstName': 'Oscar',
#        'JerseyNumber': '77',
#        'Position': 'D'},
#       'severity': 'Minor',
#       'durationMinutes': '2',
#       'type': 'Holding The Stick'}},
#     {'period': '2',
#      'time': '10:50',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '10:59',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '11:34',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '11:35',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '5875',
#        'LastName': 'Khaira',
#        'FirstName': 'Jujhar',
#        'JerseyNumber': '16',
#        'Position': 'LW'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '11:56',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '11:57',
#      'faceoff': {'awayPlayer': {'ID': '14152',
#        'LastName': 'Greenway',
#        'FirstName': 'Jordan',
#        'JerseyNumber': '18',
#        'Position': 'LW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '12:23',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5093',
#        'LastName': 'Zucker',
#        'FirstName': 'Jason',
#        'JerseyNumber': '16',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '12:42',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '13:04',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '13:11',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5001',
#        'LastName': 'Klefbom',
#        'FirstName': 'Oscar',
#        'JerseyNumber': '77',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '13:49',
#      'faceoff': {'awayPlayer': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '13:49',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '14:29',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5095',
#        'LastName': 'Brown',
#        'FirstName': 'J.T.',
#        'JerseyNumber': '23',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '14:59',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '15:05',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5001',
#        'LastName': 'Klefbom',
#        'FirstName': 'Oscar',
#        'JerseyNumber': '77',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '15:32',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4295',
#        'LastName': 'Russell',
#        'FirstName': 'Kris',
#        'JerseyNumber': '4',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '15:56',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '16:06',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '16:13',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
#        'JerseyNumber': '24',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '16:48',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '17:06',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '17:52',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '17:59',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '18:21',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5372',
#        'LastName': 'Rattie',
#        'FirstName': 'Ty',
#        'JerseyNumber': '8',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '18:29',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '12249',
#        'LastName': 'Zykov',
#        'FirstName': 'Valentin',
#        'JerseyNumber': '73',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '18:32',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'}}},
#     {'period': '2',
#      'time': '18:58',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '2',
#      'time': '18:59',
#      'faceoff': {'awayPlayer': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '2',
#      'time': '19:10',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5200',
#        'LastName': 'Chiasson',
#        'FirstName': 'Alex',
#        'JerseyNumber': '39',
#        'Position': 'RW'}}},
#     {'period': '2',
#      'time': '19:15',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '19:25',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '19:25',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'}}},
#     {'period': '2',
#      'time': '19:40',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '2',
#      'time': '19:40',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '0:00',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '0:14',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '1:03',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '1:17',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '1:51',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5039',
#        'LastName': 'Kassian',
#        'FirstName': 'Zack',
#        'JerseyNumber': '44',
#        'Position': 'RW'},
#       'assist1Player': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'},
#       'assist2Player': {'ID': '10168',
#        'LastName': 'Benning',
#        'FirstName': 'Matthew',
#        'JerseyNumber': '83',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '1:51',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '1:59',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '2:08',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '3:19',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5055',
#        'LastName': 'Foligno',
#        'FirstName': 'Marcus',
#        'JerseyNumber': '17',
#        'Position': 'LW'}}},
#     {'period': '3',
#      'time': '3:25',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '3:48',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '3:50',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '4989',
#        'LastName': 'Larsson',
#        'FirstName': 'Adam',
#        'JerseyNumber': '6',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '4:09',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '10168',
#        'LastName': 'Benning',
#        'FirstName': 'Matthew',
#        'JerseyNumber': '83',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '4:16',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5914',
#        'LastName': 'Gravel',
#        'FirstName': 'Kevin',
#        'JerseyNumber': '5',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '4:22',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '4:37',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '9630',
#        'LastName': 'Puljujarvi',
#        'FirstName': 'Jesse',
#        'JerseyNumber': '98',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '4:42',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '4:52',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '10168',
#        'LastName': 'Benning',
#        'FirstName': 'Matthew',
#        'JerseyNumber': '83',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '5:01',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '10168',
#        'LastName': 'Benning',
#        'FirstName': 'Matthew',
#        'JerseyNumber': '83',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '5:15',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '5123',
#        'LastName': 'Brodin',
#        'FirstName': 'Jonas',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '5:48',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5039',
#        'LastName': 'Kassian',
#        'FirstName': 'Zack',
#        'JerseyNumber': '44',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '5:58',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'}}},
#     {'period': '3',
#      'time': '7:03',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '10168',
#        'LastName': 'Benning',
#        'FirstName': 'Matthew',
#        'JerseyNumber': '83',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '7:09',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '7:24',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '12249',
#        'LastName': 'Zykov',
#        'FirstName': 'Valentin',
#        'JerseyNumber': '73',
#        'Position': 'LW'}}},
#     {'period': '3',
#      'time': '7:25',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '7:32',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'MIN',
#       'goalScorer': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'},
#       'assist1Player': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'},
#       'assist2Player': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '7:32',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '8:07',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '8:15',
#      'faceoff': {'awayPlayer': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '8:15',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '8:30',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '8:36',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '8:50',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '4868',
#        'LastName': 'Niederreiter',
#        'FirstName': 'Nino',
#        'JerseyNumber': '22',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '9:05',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '9:17',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3502',
#        'LastName': 'Parise',
#        'FirstName': 'Zach',
#        'JerseyNumber': '11',
#        'Position': 'LW'}}},
#     {'period': '3',
#      'time': '9:36',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '9:36',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3714',
#        'LastName': 'Suter',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '20',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '10:15',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '10:17',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '10:34',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'assist1Player': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '10:34',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '11:23',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5039',
#        'LastName': 'Kassian',
#        'FirstName': 'Zack',
#        'JerseyNumber': '44',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '11:24',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5123',
#        'LastName': 'Brodin',
#        'FirstName': 'Jonas',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '11:25',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '11:35',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5039',
#        'LastName': 'Kassian',
#        'FirstName': 'Zack',
#        'JerseyNumber': '44',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '12:26',
#      'hit': {'teamAbbreviation': 'EDM',
#       'player': {'ID': '5372',
#        'LastName': 'Rattie',
#        'FirstName': 'Ty',
#        'JerseyNumber': '8',
#        'Position': 'RW'}}},
#     {'period': '3',
#      'time': '12:26',
#      'faceoff': {'awayPlayer': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '12:53',
#      'faceoff': {'awayPlayer': {'ID': '247',
#        'LastName': 'Staal',
#        'FirstName': 'Eric',
#        'JerseyNumber': '12',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '13:09',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '13:35',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '4918',
#        'LastName': 'Spurgeon',
#        'FirstName': 'Jared',
#        'JerseyNumber': '46',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '13:48',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '13:48',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5200',
#        'LastName': 'Chiasson',
#        'FirstName': 'Alex',
#        'JerseyNumber': '39',
#        'Position': 'RW'},
#       'assist1Player': {'ID': '5875',
#        'LastName': 'Khaira',
#        'FirstName': 'Jujhar',
#        'JerseyNumber': '16',
#        'Position': 'LW'}}},
#     {'period': '3',
#      'time': '14:31',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '14:32',
#      'faceoff': {'awayPlayer': {'ID': '5124',
#        'LastName': 'Coyle',
#        'FirstName': 'Charlie',
#        'JerseyNumber': '3',
#        'Position': 'C'},
#       'homePlayer': {'ID': '3736',
#        'LastName': 'Brodziak',
#        'FirstName': 'Kyle',
#        'JerseyNumber': '28',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '16:12',
#      'hit': {'teamAbbreviation': 'MIN',
#       'player': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '16:57',
#      'blockedShot': {'teamAbbreviation': 'EDM',
#       'blocker': {'ID': '5001',
#        'LastName': 'Klefbom',
#        'FirstName': 'Oscar',
#        'JerseyNumber': '77',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '17:09',
#      'goal': {'specialTeam': 'EV',
#       'teamAbbreviation': 'EDM',
#       'goalScorer': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'},
#       'assist1Player': {'ID': '5417',
#        'LastName': 'Draisaitl',
#        'FirstName': 'Leon',
#        'JerseyNumber': '29',
#        'Position': 'C'},
#       'assist2Player': {'ID': '5576',
#        'LastName': 'McDavid',
#        'FirstName': 'Connor',
#        'JerseyNumber': '97',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '17:09',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '17:35',
#      'shot': {'teamAbbreviation': 'MIN',
#       'shooter': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '17:48',
#      'penalty': {'teamAbbreviation': 'MIN',
#       'penalizedPlayer': {'ID': '5615',
#        'LastName': 'Eriksson-Ek',
#        'FirstName': 'Joel',
#        'JerseyNumber': '14',
#        'Position': 'C'},
#       'severity': 'Minor',
#       'durationMinutes': '2',
#       'type': 'Slashing'}},
#     {'period': '3',
#      'time': '17:48',
#      'faceoff': {'awayPlayer': {'ID': '3819',
#        'LastName': 'Fehr',
#        'FirstName': 'Eric',
#        'JerseyNumber': '21',
#        'Position': 'C'},
#       'homePlayer': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'},
#       'wonBy': 'MIN'}},
#     {'period': '3',
#      'time': '18:07',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5112',
#        'LastName': 'Spooner',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '23',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '18:08',
#      'faceoff': {'awayPlayer': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'},
#       'homePlayer': {'ID': '4299',
#        'LastName': 'Lucic',
#        'FirstName': 'Milan',
#        'JerseyNumber': '27',
#        'Position': 'LW'},
#       'wonBy': 'EDM'}},
#     {'period': '3',
#      'time': '18:14',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '5464',
#        'LastName': 'Nurse',
#        'FirstName': 'Darnell',
#        'JerseyNumber': '25',
#        'Position': 'D'}}},
#     {'period': '3',
#      'time': '18:20',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '4639',
#        'LastName': 'Hendricks',
#        'FirstName': 'Matt',
#        'JerseyNumber': '15',
#        'Position': 'C'}}},
#     {'period': '3',
#      'time': '19:29',
#      'shot': {'teamAbbreviation': 'EDM',
#       'shooter': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'}}}]}}}

# %%
## Building a loop to go through each season,each team, each game
## What is missing is the full list of team IDS, and including a Try and Except.
## we can use this lopp to build the dataframe of the stats we need.
##This is a test on printing Blocked shots int he first 5 games over three seasons

TargetSeasons=["2018-2019-regular",
              "2017-2018-regular",
              "2016-2017-regular",]

for season in TargetSeasons:
    for team in range (1,10):
        for game in range (1,5):
            TeamGameLogs = msf.msf_get_data(league='nhl',season=season,feed='team_gamelogs',team=team, format='json')
            BlockedShots=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["BlockedShots"]["#text"]
            print (BlockedShots)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-46b19a0ae95f> in <module>
#      12         for game in range (1,5):
#      13             TeamGameLogs = msf.msf_get_data(league='nhl',season=season,feed='team_gamelogs',team=team, format='json')
# ---> 14             BlockedShots=TeamGameLogs["teamgamelogs"]["gamelogs"][game]["stats"]["BlockedShots"]["#text"]
#      15             print (BlockedShots)
#
# KeyError: 'gamelogs'

# %%
#win=TeamGameLogs["teamgamelogs"]["gamelogs"][GameNo]["stats"]["Wins"]["#text"]
#GoalsAgainst=TeamGameLogs["teamgamelogs"]["gamelogs"][GameNo]["stats"]["GoalsAgainst"]["#text"]
#PenaltyKillPercent=TeamGameLogs["teamgamelogs"]["gamelogs"][GameNo]["stats"]["PenaltyKillPercent"]["#text"]


TeamGameLogs = msf.msf_get_data(league='nhl',season='2018-2019-regular',feed='team_gamelogs',team=5, format='json')

TeamGameLogs
# Out:
# {'teamgamelogs': {'lastUpdatedOn': '2019-10-24 1:24:40 PM'}}

# %%
#available feeds

['cumulative_player_stats',
 'full_game_schedule',
 'daily_game_schedule',
 'daily_player_stats',
 'game_boxscore',
 'scoreboard',
 'game_playbyplay', 
 'player_gamelogs',
 'team_gamelogs',
 'roster_players',
 'game_startinglineup',
 'active_players',
 'overall_team_standings',
 'conference_team_standings',
 'division_team_standings',
 'playoff_team_standings',
 'player_injuries',
 'daily_dfs',
 'current_season',
 'latest_updates']
