# %%
from ohmysportsfeedspy import MySportsFeeds
import simplejson as json

# %%
#url="https://api.mysportsfeeds.com/v1.2/pull/nhl/2019-2020-regular/game_playbyplay.json?gameid=20191012-WSH-DAL"
#apikey_token="56cfc058-77c9-4e57-829a-07058c"
#password="6dRSvQq4F3evp!C"

msf = MySportsFeeds(version="1.2")
msf.authenticate(API Key, Password)

# %%
#Game by Game stat
#Example 
output = msf.msf_get_data(league='nhl',season='2018-2019-regular',feed='game_playbyplay',gameid="20181207-MIN-EDM", format='json')
output
# Out:
# {'gameplaybyplay': {'lastUpdatedOn': '2019-10-24 10:16:18 AM',
#   'game': {'date': '2018-12-07',
#    'time': '9:00PM',
#    'awayTeam': {'ID': '25',
#     'City': 'Minnesota',
#     'Name': 'Wild',
#     'Abbreviation': 'MIN'},
#    'homeTeam': {'ID': '24',
#     'City': 'Edmonton',
#     'Name': 'Oilers',
#     'Abbreviation': 'EDM'},
#    'location': 'Rogers Place'},
#   'plays': {'play': [{'period': '1',
#      'time': '0:00',
#      'faceoff': {'awayPlayer': {'ID': '5126',
#        'LastName': 'Granlund',
#        'FirstName': 'Mikael',
#        'JerseyNumber': '64',
#        'Position': 'RW'},
#       'homePlayer': {'ID': '4993',
#        'LastName': 'Nugent-Hopkins',
#        'FirstName': 'Ryan',
#        'JerseyNumber': '93',
#        'Position': 'C'},
#       'wonBy': 'EDM'}},
#     {'period': '1',
#      'time': '0:28',
#      'blockedShot': {'teamAbbreviation': 'MIN',
#       'blocker': {'ID': '5125',
#        'LastName': 'Dumba',
#        'FirstName': 'Matt',
# ...

# %%
TeamGameLogs = msf.msf_get_data(league='nhl',season='2018-2019-regular',feed='team_gamelogs',team="1", format='json')
TeamGameLogs["teamgamelogs"]["gamelogs"][50]["stats"]
# Out:
# {'Wins': {'@category': 'Standings', '@abbreviation': 'W', '#text': '1'},
#  'Losses': {'@category': 'Standings', '@abbreviation': 'L', '#text': '0'},
#  'OvertimeWins': {'@category': 'Standings',
#   '@abbreviation': 'OTW',
#   '#text': '0'},
#  'OvertimeLosses': {'@category': 'Standings',
#   '@abbreviation': 'OTL',
#   '#text': '0'},
#  'ShootoutWins': {'@category': 'Standings',
#   '@abbreviation': 'SOW',
#   '#text': '1'},
#  'ShootoutLosses': {'@category': 'Standings',
#   '@abbreviation': 'SOL',
#   '#text': '0'},
#  'GoalsFor': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GF',
#   '#text': '0'},
#  'GoalsAgainst': {'@category': 'Miscellaneous',
#   '@abbreviation': 'GA',
#   '#text': '0'},
#  'FaceoffWins': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O W',
#   '#text': '22'},
#  'FaceoffLosses': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O L',
#   '#text': '31'},
#  'FaceoffPercent': {'@category': 'Faceoffs',
#   '@abbreviation': 'F/O %',
# ...

# %%
#available feeds

['cumulative_player_stats',
 'full_game_schedule',
 'daily_game_schedule',
 'daily_player_stats',
 'game_boxscore',
 'scoreboard',
 'game_playbyplay', 
 'player_gamelogs',
 'team_gamelogs',
 'roster_players',
 'game_startinglineup',
 'active_players',
 'overall_team_standings',
 'conference_team_standings',
 'division_team_standings',
 'playoff_team_standings',
 'player_injuries',
 'daily_dfs',
 'current_season',
 'latest_updates']
